# %% [markdown]
# # 10 Minutes to cuDF's pandas accelerator mode (cudf.pandas)
#
# cuDF is a Python GPU DataFrame library (built on the Apache Arrow columnar memory format) for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API in the style of pandas.
#
# As of the v23.10 release, cuDF now provides a pandas accelerator mode (`cudf.pandas`), allowing you to bring accelerated computing to your pandas workflows without requiring any code change.
#
# This notebook is a short introduction to `cudf.pandas`.

# %% [markdown]
# # ⚠️ Verify your setup
#
# First, we'll verify that you are running with an NVIDIA GPU and that cuDF is available.
#
# If you haven't installed cuDF, please visit https://rapids.ai/#quick-start to choose your favorite installation method.

# %%
# !nvidia-smi  # this should display information about available GPUs
# Out:
# Sat Jan 20 06:59:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:1E.0 Off |                    0 |
# | N/A   25C    P0              26W /  70W |      2MiB / 15360MiB |      6%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# With our GPU-enabled Databricks runtime active, we'll now install cuDF.
#
# If you're interested in installing on other platforms, please visit https://rapids.ai/#quick-start to learn more.

# %%
# !pip install --extra-index-url=https://pypi.nvidia.com cudf-cu11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cudf-cu11
#   Downloading https://pypi.nvidia.com/cudf-cu11/cudf_cu11-23.12.1-cp310-cp310-manylinux_2_28_x86_64.whl (506.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 506.4/506.4 MB 169.0
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.4/506.4 MB 1.3 MB/s eta 0:00:00
# Collecting cubinlinker-cu11
#   Downloading https://pypi.nvidia.com/cubinlinker-cu11/cubinlinker_cu11-0.3.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 100.7 MB/s eta 0:00:00
# Collecting numba<0.58,>=0.57
#   Downloading numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5,>=4.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.23.3)
# Collecting ptxcompiler-cu11
#   Downloading https://pypi.nvidia.com/ptxcompiler-cu11/ptxcompiler_cu11-0.7.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 90.2 MB/s eta 0:00:00
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (5.3.1)
# Collecting rmm-cu11==23.12.*
#   Downloading https://pypi.nvidia.com/rmm-cu11/rmm_cu11-23.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 96.8 MB/s eta 0:00:00
# Collecting nvtx>=0.2.1
#   Downloading nvtx-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.4/582.4 kB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25,>=1.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.23.5)
# Collecting rich
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.5.0)
# Collecting cupy-cuda11x>=12.0.0
#   Downloading cupy_cuda11x-13.0.0-cp310-cp310-manylinux2014_x86_64.whl (95.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 MB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas<1.6.0dev0,>=1.3 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.5.3)
# Collecting cuda-python<12.0a0,>=11.7.1
#   Downloading cuda_python-11.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 58.5 MB/s eta 0:00:00
# Collecting pyarrow<15.0.0a0,>=14.0.1
#   Downloading pyarrow-14.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 45.3 MB/s eta 0:00:00
# Collecting fastrlock>=0.5
#   Downloading fastrlock-0.8.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 9.7 MB/s eta 0:00:00
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 41.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2023.3)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.10/site-packages (from rich->cudf-cu11) (2.15.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.3->cudf-cu11) (1.16.0)
# Installing collected packages: ptxcompiler-cu11, nvtx, fastrlock, cuda-python, cubinlinker-cu11, pyarrow, mdurl, llvmlite, fsspec, cupy-cuda11x, numba, markdown-it-py, rmm-cu11, rich, cudf-cu11
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 8.0.0
#     Not uninstalling pyarrow at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-b1e20946-7512-4941-a81d-22b38785ae55
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
# Successfully installed cubinlinker-cu11-0.3.0.post1 cuda-python-11.8.3 cudf-cu11-23.12.1 cupy-cuda11x-13.0.0 fastrlock-0.8.2 fsspec-2023.12.2 llvmlite-0.40.1 markdown-it-py-3.0.0 mdurl-0.1.2 numba-0.57.1 nvtx-0.2.8 ptxcompiler-cu11-0.7.0.post1 pyarrow-14.0.2 rich-13.7.0 rmm-cu11-23.12.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import cudf  # this should work without any errors

# %% [markdown]
# We'll also install `plotly-express` for visualizing data.

# %%
# !pip install --upgrade pip plotly_express==0.4.1 nbformat
# Out:
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b1e20946-7512-4941-a81d-22b38785ae55/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.8 MB/s eta 0:00:00
# Collecting plotly_express==0.4.1
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting nbformat
#   Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 12.6 MB/s eta 0:00:00
# Collecting patsy>=0.5
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 16.2 MB/s eta 0:00:00
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in /databricks/python3/lib/python3.10/site-packages (from plotly_express==0.4.1) (1.23.5)
# Requirement already satisfied: pandas>=0.20.0 in /databricks/python3/lib/python3.10/site-packages (from plotly_express==0.4.1) (1.5.3)
# Collecting plotly>=4.1.0
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 59.9 MB/s eta 0:00:00
# Collecting scipy>=0.18
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 40.5 MB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat) (5.3.1)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=5.1 in /databricks/python3/lib/python3.10/site-packages (from nbformat) (5.9.0)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.32.1-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.0 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express==0.4.1) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express==0.4.1) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5->plotly_express==0.4.1) (1.16.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from plotly>=4.1.0->plotly_express==0.4.1) (23.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat) (2.6.2)
# Installing collected packages: fastjsonschema, tenacity, scipy, rpds-py, pip, patsy, attrs, referencing, plotly, statsmodels, jsonschema-specifications, plotly_express, jsonschema, nbformat
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 nbformat-5.9.2 patsy-0.5.6 pip-23.3.2 plotly-5.18.0 plotly_express-0.4.1 referencing-0.32.1 rpds-py-0.17.1 scipy-1.11.4 statsmodels-0.14.1 tenacity-8.2.3

# %% [markdown]
# # Download the data
#
# The data we'll be working with is the [Parking Violations Issued - Fiscal Year 2022](https://data.cityofnewyork.us/City-Government/Parking-Violations-Issued-Fiscal-Year-2022/7mxj-7a6y) dataset from NYC Open Data.
#
# We're downloading a copy of this dataset from an s3 bucket hosted by NVIDIA to provide faster download speeds. We'll start by downloading the data. This should take about 30 seconds.
#
# ## Data License and Terms
# As this dataset originates from the NYC Open Data Portal, it's governed by their license and terms of use.
#
# ### Are there restrictions on how I can use Open Data?
#
# > Open Data belongs to all New Yorkers. There are no restrictions on the use of Open Data. Refer to Terms of Use for more information.
#
# ### [Terms of Use](https://opendata.cityofnewyork.us/overview/#termsofuse)
#
# > By accessing datasets and feeds available through NYC Open Data, the user agrees to all of the Terms of Use of NYC.gov as well as the Privacy Policy for NYC.gov. The user also agrees to any additional terms of use defined by the agencies, bureaus, and offices providing data. Public data sets made available on NYC Open Data are provided for informational purposes. The City does not warranty the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set made available on NYC Open Data, nor are any such warranties to be implied or inferred with respect to the public data sets furnished therein.
#
# > The City is not liable for any deficiencies in the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set, or application utilizing such data set, provided by any third party.
#
# > Submitting City Agencies are the authoritative source of data available on NYC Open Data. These entities are responsible for data quality and retain version control of data sets and feeds accessed on the Site. Data may be updated, corrected, or refreshed at any time.

# %%
# !wget https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Out:
# --2024-01-20 07:02:09--  https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Resolving data.rapids.ai (data.rapids.ai)... 204.246.191.16, 204.246.191.103, 204.246.191.75, ...
# Connecting to data.rapids.ai (data.rapids.ai)|204.246.191.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477161608 (455M) [binary/octet-stream]
# Saving to: ‘nyc_parking_violations_2022.parquet’
#
# nyc_parking_violati 100%[===================>] 455.06M  27.7MB/s    in 16s
#
# 2024-01-20 07:02:25 (29.2 MB/s) - ‘nyc_parking_violations_2022.parquet’ saved [477161608/477161608]

# %% [markdown]
# # Analysis using Standard Pandas
#
# First, let's use Pandas to read in some columns of the dataset:

# %%
import pandas as pd

# %%
# read 5 columns data:
df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

# view a random sample of 10 rows:
df.sample(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>Vehicle Body Type</th>
#       <th>Issue Date</th>
#       <th>Summons Number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3617922</th>
#       <td>FL</td>
#       <td>20A-No Parking (Non-COM)</td>
#       <td>4DSD</td>
#       <td>09/17/2021</td>
#       <td>8856492490</td>
#     </tr>
#     <tr>
#       <th>2676451</th>
#       <td>NY</td>
#       <td>46B-Double Parking (Com-100Ft)</td>
#       <td>VAN</td>
#       <td>08/04/2021</td>
#       <td>8963434515</td>
#     </tr>
#     <tr>
#       <th>6750213</th>
#       <td>NY</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>SUBN</td>
#       <td>12/07/2021</td>
#       <td>4759508480</td>
#     </tr>
#     <tr>
#       <th>8116279</th>
#       <td>NY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>4DSD</td>
#       <td>12/28/2021</td>
#       <td>8846568280</td>
#     </tr>
#     <tr>
#       <th>7593706</th>
#       <td>NY</td>
#       <td>38-Failure to Dsplay Meter Rec</td>
#       <td>SUBN</td>
#       <td>12/16/2021</td>
#       <td>8885932939</td>
#     </tr>
#     <tr>
#       <th>9800674</th>
#       <td>NY</td>
#       <td>19-No Stand (bus stop)</td>
#       <td>SUBN</td>
#       <td>01/27/2022</td>
#       <td>8894054690</td>
#     </tr>
#     <tr>
#       <th>2775199</th>
#       <td>NY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>SUBN</td>
#       <td>08/12/2021</td>
#       <td>8983980837</td>
#     </tr>
#     <tr>
#       <th>3879001</th>
#       <td>NY</td>
#       <td>50-Crosswalk</td>
#       <td>4DSD</td>
#       <td>09/16/2021</td>
#       <td>8954009300</td>
#     </tr>
#     <tr>
#       <th>6563990</th>
#       <td>NY</td>
#       <td>16A-No Std (Com Veh) Non-COM</td>
#       <td>4DSD</td>
#       <td>10/27/2021</td>
#       <td>8965979067</td>
#     </tr>
#     <tr>
#       <th>2605823</th>
#       <td>NY</td>
#       <td>48-Bike Lane</td>
#       <td>VAN</td>
#       <td>08/03/2021</td>
#       <td>8949986000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Next, we'll try to answer a few questions using the data.

# %% [markdown]
# ## Which parking violation is most commonly committed by vehicles from various U.S states?
#
# Each record in our dataset contains the state of registration of the offending vehicle, and the type of parking offence. Let's say we want to get the most common type of offence for vehicles registered in different states. We can do this in Pandas using a combination of [value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html) and [GroupBy.head](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.head.html):

# %%
(
    df[["Registration State", "Violation Description"]]  # get only these two columns
    .value_counts()  # get the count of offences per state and per type of offence
    .groupby("Registration State")  # group by state
    .head(
        1
    )  # get the first row in each group (the type of offence with the largest count)
    .sort_index()  # sort by state name
    .reset_index()
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99</td>
#       <td>74-Missing Display Plate</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AB</td>
#       <td>14-No Standing</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AK</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AL</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3668</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AR</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>537</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>VT</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3024</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>WA</td>
#       <td>21-No Parking (street clean)</td>
#       <td>3732</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>WI</td>
#       <td>14-No Standing</td>
#       <td>1639</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>WV</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>WY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>138</td>
#     </tr>
#   </tbody>
# </table>
# <p>65 rows × 3 columns</p>
# </div>

# %% [markdown]
# The code above uses [method chaining](https://tomaugspurger.net/posts/method-chaining/) to combine a series of operations into a single statement. You might find it useful to break the code up into multiple statements and inspect each of the intermediate results!

# %% [markdown]
# ## Which vehicle body types are most frequently involved in parking violations?
#
# We can also investigate which vehicle body types most commonly appear in parking violations

# %%
(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th>Vehicle Body Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SUBN</th>
#       <td>6449007</td>
#     </tr>
#     <tr>
#       <th>4DSD</th>
#       <td>4402991</td>
#     </tr>
#     <tr>
#       <th>VAN</th>
#       <td>1317899</td>
#     </tr>
#     <tr>
#       <th>DELV</th>
#       <td>436430</td>
#     </tr>
#     <tr>
#       <th>PICK</th>
#       <td>429798</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>CARY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ISUZ</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>IXMR</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BILB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ONEL</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>966 rows × 1 columns</p>
# </div>

# %% [markdown]
# ## How do parking violations vary across days of the week?

# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# Out[10]: issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %% [markdown]
# It looks like there are fewer violations on weekends, which makes sense! During the week, more people are driving in New York City.

# %% [markdown]
# ## Let's time it!
#
# Loading and processing this data took a little time. Let's measure how long these pipelines take in Pandas:

# %%
# %%time

import pandas as pd

# read 5 columns data:
df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

# Which parking violation is most commonly committed by vehicles from various U.S states?
(
    df[["Registration State", "Violation Description"]]
    .value_counts()
    .groupby("Registration State")
    .head(1)
    .sort_index()
    .reset_index()
)
# Out:
# CPU times: user 10.9 s, sys: 3.02 s, total: 13.9 s
# Wall time: 11.2 s
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99</td>
#       <td>74-Missing Display Plate</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AB</td>
#       <td>14-No Standing</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AK</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AL</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3668</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AR</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>537</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>VT</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3024</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>WA</td>
#       <td>21-No Parking (street clean)</td>
#       <td>3732</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>WI</td>
#       <td>14-No Standing</td>
#       <td>1639</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>WV</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>WY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>138</td>
#     </tr>
#   </tbody>
# </table>
# <p>65 rows × 3 columns</p>
# </div>

# %%
# %%time

# Which vehicle body types are most frequently involved in parking violations?
(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)
# Out:
# CPU times: user 2.48 s, sys: 173 ms, total: 2.65 s
# Wall time: 2.64 s
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th>Vehicle Body Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SUBN</th>
#       <td>6449007</td>
#     </tr>
#     <tr>
#       <th>4DSD</th>
#       <td>4402991</td>
#     </tr>
#     <tr>
#       <th>VAN</th>
#       <td>1317899</td>
#     </tr>
#     <tr>
#       <th>DELV</th>
#       <td>436430</td>
#     </tr>
#     <tr>
#       <th>PICK</th>
#       <td>429798</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>CARY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ISUZ</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>IXMR</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BILB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ONEL</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>966 rows × 1 columns</p>
# </div>

# %%
# %%time

# How do parking violations vary across days of the week?
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 5.44 s, sys: 725 ms, total: 6.17 s
# Wall time: 6.15 s
# Out[13]: issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %% [markdown]
# # Using cuDF's pandas accelerator mode (cudf.pandas)
#
# Now, let's re-run the Pandas code above with the `cudf.pandas` extension loaded.
#
# Typically, you should load the `cudf.pandas` extension as the first step in your notebook, before importing any modules. Here, we explicitly restart the kernel to simulate that behavior.

# %%
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# Out[14]: {'status': 'ok', 'restart': True}

# %%
# !pip install --extra-index-url=https://pypi.nvidia.com cudf-cu11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cudf-cu11
#   Using cached https://pypi.nvidia.com/cudf-cu11/cudf_cu11-23.12.1-cp310-cp310-manylinux_2_28_x86_64.whl (506.4 MB)
# Requirement already satisfied: cachetools in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (5.3.1)
# Collecting rich
#   Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.3 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.5.3)
# Requirement already satisfied: numpy<1.25,>=1.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.23.5)
# Collecting fsspec>=0.6.0
#   Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.5.0)
# Collecting ptxcompiler-cu11
#   Using cached https://pypi.nvidia.com/ptxcompiler-cu11/ptxcompiler_cu11-0.7.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
# Collecting pyarrow<15.0.0a0,>=14.0.1
#   Using cached pyarrow-14.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.0 MB)
# Collecting cubinlinker-cu11
#   Using cached https://pypi.nvidia.com/cubinlinker-cu11/cubinlinker_cu11-0.3.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
# Collecting numba<0.58,>=0.57
#   Using cached numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (23.1)
# Requirement already satisfied: protobuf<5,>=4.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.23.3)
# Collecting nvtx>=0.2.1
#   Using cached nvtx-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
# Collecting rmm-cu11==23.12.*
#   Using cached https://pypi.nvidia.com/rmm-cu11/rmm_cu11-23.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Collecting cuda-python<12.0a0,>=11.7.1
#   Using cached cuda_python-11.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.7 MB)
# Collecting cupy-cuda11x>=12.0.0
#   Using cached cupy_cuda11x-13.0.0-cp310-cp310-manylinux2014_x86_64.whl (95.3 MB)
# Collecting fastrlock>=0.5
#   Using cached fastrlock-0.8.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (51 kB)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Using cached llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2.8.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.10/site-packages (from rich->cudf-cu11) (2.15.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.3->cudf-cu11) (1.16.0)
# Installing collected packages: ptxcompiler-cu11, nvtx, fastrlock, cuda-python, cubinlinker-cu11, pyarrow, mdurl, llvmlite, fsspec, cupy-cuda11x, numba, markdown-it-py, rmm-cu11, rich, cudf-cu11
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 8.0.0
#     Not uninstalling pyarrow at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-be6632ae-b7e8-4319-986f-cf9afbb8fb7b
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
# Successfully installed cubinlinker-cu11-0.3.0.post1 cuda-python-11.8.3 cudf-cu11-23.12.1 cupy-cuda11x-13.0.0 fastrlock-0.8.2 fsspec-2023.12.2 llvmlite-0.40.1 markdown-it-py-3.0.0 mdurl-0.1.2 numba-0.57.1 nvtx-0.2.8 ptxcompiler-cu11-0.7.0.post1 pyarrow-14.0.2 rich-13.7.0 rmm-cu11-23.12.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade pip plotly_express==0.4.1 nbformat
# Out:
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-be6632ae-b7e8-4319-986f-cf9afbb8fb7b/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Using cached pip-23.3.2-py3-none-any.whl (2.1 MB)
# Collecting plotly_express==0.4.1
#   Using cached plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting nbformat
#   Using cached nbformat-5.9.2-py3-none-any.whl (77 kB)
# Requirement already satisfied: pandas>=0.20.0 in /databricks/python3/lib/python3.10/site-packages (from plotly_express==0.4.1) (1.5.3)
# Collecting patsy>=0.5
#   Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Collecting statsmodels>=0.9.0
#   Using cached statsmodels-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
# Requirement already satisfied: numpy>=1.11 in /databricks/python3/lib/python3.10/site-packages (from plotly_express==0.4.1) (1.23.5)
# Collecting scipy>=0.18
#   Using cached scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
# Collecting plotly>=4.1.0
#   Using cached plotly-5.18.0-py3-none-any.whl (15.6 MB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.21.1-py3-none-any.whl (85 kB)
# Requirement already satisfied: traitlets>=5.1 in /databricks/python3/lib/python3.10/site-packages (from nbformat) (5.9.0)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat) (5.3.1)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Collecting attrs>=22.2.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.32.1-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express==0.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express==0.4.1) (2023.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5->plotly_express==0.4.1) (1.16.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from plotly>=4.1.0->plotly_express==0.4.1) (23.1)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat) (2.6.2)
# Installing collected packages: fastjsonschema, tenacity, scipy, rpds-py, pip, patsy, attrs, referencing, plotly, statsmodels, jsonschema-specifications, plotly_express, jsonschema, nbformat
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 nbformat-5.9.2 patsy-0.5.6 pip-23.3.2 plotly-5.18.0 plotly_express-0.4.1 referencing-0.32.1 rpds-py-0.17.1 scipy-1.11.4 statsmodels-0.14.1 tenacity-8.2.3

# %%
# %load_ext cudf.pandas

# %%
# %%time

import pandas as pd

# read 5 columns data:
df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

# Which parking violation is most commonly committed by vehicles from various U.S states?
(
    df[["Registration State", "Violation Description"]]
    .value_counts()
    .groupby("Registration State")
    .head(1)
    .sort_index()
    .reset_index()
)
# Out:
# CPU times: user 483 ms, sys: 254 ms, total: 737 ms
# Wall time: 872 ms
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99</td>
#       <td>74-Missing Display Plate</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AB</td>
#       <td>14-No Standing</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AK</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AL</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3668</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AR</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>537</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>VT</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3024</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>WA</td>
#       <td>21-No Parking (street clean)</td>
#       <td>3732</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>WI</td>
#       <td>14-No Standing</td>
#       <td>1639</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>WV</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>WY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>138</td>
#     </tr>
#   </tbody>
# </table>
# <p>65 rows × 3 columns</p>
# </div>

# %%
# %%time

# Which vehicle body types are most frequently involved in parking violations?
(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)
# Out:
# CPU times: user 38.9 ms, sys: 7.33 ms, total: 46.3 ms
# Wall time: 45.8 ms
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th>Vehicle Body Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SUBN</th>
#       <td>6449007</td>
#     </tr>
#     <tr>
#       <th>4DSD</th>
#       <td>4402991</td>
#     </tr>
#     <tr>
#       <th>VAN</th>
#       <td>1317899</td>
#     </tr>
#     <tr>
#       <th>DELV</th>
#       <td>436430</td>
#     </tr>
#     <tr>
#       <th>PICK</th>
#       <td>429798</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>YANT</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>YBSD</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>YEL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>YL</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Z1UT</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>966 rows × 1 columns</p>
# </div>

# %%
# %%time

# How do parking violations vary across days of the week?
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 181 ms, sys: 55.6 ms, total: 236 ms
# Wall time: 237 ms
# Out[6]: issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %% [markdown]
# Much faster! Operations that took 5-20 seconds can now potentially finish in just milliseconds without changing any code.

# %% [markdown]
# # Understanding Performance
#
# cuDF's pandas accelerator mode provides profiling utilities to help you better understand performance. With these tools, you can identify which parts of your code ran on the GPU and which parts ran on the CPU.
#
# They're accessible in the `cudf.pandas` namespace since the `cudf.pandas` extension was loaded above with `load_ext cudf.pandas`.
#
# #### Colab Note
# If you're running in Colab, the first time you run use the profiler it may take 10+ seconds due to Colab's debugger interacting with the built-in Python function [sys.settrace](https://docs.python.org/3/library/sys.html#sys.settrace) that we use for profiling. For demo purposes, this isn't an issue. Just run the cell again.
#
# ## Profiling Functionality
#
# We can generate a per-function profile:

# %%
# %%cudf.pandas.profile
#
# small_df = pd.DataFrame({'a': [0, 1, 2], 'b': ["x", "y", "z"]})
# small_df = pd.concat([small_df, small_df])
#
# axis = 0
# for i in range(0, 2):
#     small_df.min(axis=axis)
#     axis = 1
#
# counts = small_df.groupby("a").b.count()
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-be6632ae-b7e8-4319-986f-cf9afbb8fb7b/lib/python3.10/site-packages/cudf/core/dataframe.py:5933: UserWarning: Row-wise operations currently only support int, float and bool dtypes. Non numeric columns are ignored.
#   warnings.warn(msg)
#
#                            Total time elapsed: 92.818 seconds
#                          5 GPU function calls in 92.383 seconds
#                          1 CPU function calls in 0.022 seconds
#
#                                          Stats
#
# ┏━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃          ┃ GPU      ┃ GPU      ┃ GPU      ┃ CPU       ┃ CPU      ┃ CPU       ┃
# ┃ Function ┃ ncalls   ┃ cumtime  ┃ percall  ┃ ncalls    ┃ cumtime  ┃ percall   ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ DataFra… │ 1        │ 0.005    │ 0.005    │ 0         │ 0.000    │ 0.000     │
# │ concat   │ 1        │ 0.013    │ 0.013    │ 0         │ 0.000    │ 0.000     │
# │ DataFra… │ 1        │ 92.355   │ 92.355   │ 1         │ 0.022    │ 0.022     │
# │ DataFra… │ 1        │ 0.001    │ 0.001    │ 0         │ 0.000    │ 0.000     │
# │ SeriesG… │ 1        │ 0.009    │ 0.009    │ 0         │ 0.000    │ 0.000     │
# └──────────┴──────────┴──────────┴──────────┴───────────┴──────────┴───────────┘
# Not all pandas operations ran on the GPU. The following functions required CPU
# fallback:
#
# - DataFrame.min
#
# To request GPU support for any of these functions, please file a Github issue
# here: ]8;id=245279;https://github.com/rapidsai/cudf/issues/new?assignees=&labels=%3F+-+Needs+Triage%2C+feature+request&projects=&template=pandas_function_request.md&title=%5BFEA%5D\https://github.com/rapidsai/cudf/issues/new/choose]8;;\.

# %%
# %%cudf.pandas.line_profile
#
# small_df = pd.DataFrame({'a': [0, 1, 2], 'b': ["x", "y", "z"]})
# small_df = pd.concat([small_df, small_df])
#
# axis = 0
# for i in range(0, 2):
#     small_df.min(axis=axis)
#     axis = 1
#
# counts = small_df.groupby("a").b.count()
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-be6632ae-b7e8-4319-986f-cf9afbb8fb7b/lib/python3.10/site-packages/cudf/core/dataframe.py:5933: UserWarning: Row-wise operations currently only support int, float and bool dtypes. Non numeric columns are ignored.
#   warnings.warn(msg)
#
#                            Total time elapsed: 1.508 seconds
#
#                                          Stats
#
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Line no. ┃ Line                                  ┃ GPU TIME(s) ┃ CPU TIME(s) ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 2        │     small_df = pd.DataFrame({'a': [0… │ 0.004868825 │             │
# │          │                                       │             │             │
# │ 3        │     small_df = pd.concat([small_df, … │ 0.012540610 │             │
# │          │                                       │             │             │
# │ 5        │     axis = 0                          │             │             │
# │          │                                       │             │             │
# │ 6        │     for i in range(0, 2):             │             │             │
# │          │                                       │             │             │
# │ 7        │         small_df.min(axis=axis)       │ 0.033853176 │ 0.021327349 │
# │          │                                       │             │             │
# │ 8        │         axis = 1                      │             │             │
# │          │                                       │             │             │
# │ 10       │     counts = small_df.groupby("a").b… │ 0.013163952 │             │
# │          │                                       │             │             │
# └──────────┴───────────────────────────────────────┴─────────────┴─────────────┘

# %% [markdown]
# ## Behind the scenes: What's going on here?
#
# When you load cuDF's pandas accelerator mode, Pandas types like `Series` and `DataFrame` are replaced by proxy objects that dispatch operations to cuDF when possible. We can verify that `cudf.pandas` is active by looking at our `pd` variable:

# %%
pd
# Out:
# Out[9]: <module 'pandas' (ModuleAccelerator(fast=cudf, slow=pandas))>

# %% [markdown]
# As a result, all pandas functions, methods, and created objects are proxies:

# %%
type(pd.read_csv)
# Out:
# Out[10]: cudf.pandas.fast_slow_proxy._FunctionProxy

# %% [markdown]
# Operations supported by cuDF will be **very** fast:

# %%
# %%time
df.count(axis=0)
# Out:
# CPU times: user 393 ms, sys: 356 ms, total: 749 ms
# Wall time: 749 ms
# Out[11]: Registration State       15435607
# Violation Description    15117819
# Vehicle Body Type        15402365
# Issue Date               15435607
# Summons Number           15435607
# issue_weekday            15435607
# dtype: int64

# %% [markdown]
# Operations not supported by cuDF will be slower, as they fall back to using Pandas (copying data between the CPU and GPU under the hood as needed). For example, cuDF does not currently support the `axis=` parameter to the `count` method. So this operation will run on the CPU and be noticeably slower than the previous one.

# %%
# %%time
df.count(
    axis=1
)  # This will use pandas, because cuDF doesn't support axis=1 for the .count() method
# Out:
# CPU times: user 13.4 s, sys: 2.81 s, total: 16.2 s
# Wall time: 16 s
# Out[12]: 0           5
# 1           5
# 2           5
# 3           5
# 4           5
#            ..
# 15435602    6
# 15435603    6
# 15435604    6
# 15435605    6
# 15435606    6
# Length: 15435607, dtype: int64

# %% [markdown]
# But the story doesn't end here. We often need to mix our own code with third-party libraries that other people have written. Many of these libraries accept pandas objects as inputs.

# %% [markdown]
# # Using third-party libraries with cuDF's pandas accelerator mode
#
# You can pass Pandas objects to third-party libraries when using `cudf.pandas`, just like you would when using regular Pandas.
#
# Below, we show an example of using [plotly-express](https://plotly.com/python/plotly-express/) to visualize the data we've been processing:

# %% [markdown]
# ## Visualizing which states have more pickup trucks relative to other vehicles?

# %%
import plotly.express as px

df = df.rename(
    columns={
        "Registration State": "reg_state",
        "Vehicle Body Type": "vehicle_type",
    }
)

# vehicle counts per state:
counts = df.groupby("reg_state").size().sort_index()
# vehicles with type "PICK" (Pickup Truck)
pickup_counts = df.where(df["vehicle_type"] == "PICK").groupby("reg_state").size()
# percentage of pickup trucks by state:
pickup_frac = ((pickup_counts / counts) * 100).rename("% Pickup Trucks")
del pickup_frac["MB"]  # (Manitoba is a huge outlier!)

# plot the results:
pickup_frac = pickup_frac.reset_index()
fig = px.choropleth(
    pickup_frac,
    locations="reg_state",
    color="% Pickup Trucks",
    locationmode="USA-states",
    scope="usa",
)

fig.show(renderer="databricks")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="bbcee1b0-0701-4cd5-9b39-cca75a0e5124" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbcee1b0-0701-4cd5-9b39-cca75a0e5124")) {                    Plotly.newPlot(                        "bbcee1b0-0701-4cd5-9b39-cca75a0e5124",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"reg_state=%{location}\u003cbr\u003e% Pickup Trucks=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["99","AB","AK","AL","AR","AZ","BC","CA","CO","CT","DC","DE","DP","FL","FO","GA","GV","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","MX","NB","NC","ND","NE","NH","NJ","NM","NS","NT","NV","NY","OH","OK","ON","OR","PA","PE","PR","QB","RI","SC","SD","SK","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[0.13389536325316143,3.361344537815126,3.231017770597738,1.7287093010923744,2.394492666866208,1.9063117517145183,2.380952380952381,1.5011320889269222,2.5121819166215484,2.2371009577431846,0.8736415938632005,1.5900925005733506,0.10559662090813093,1.240151879359909,5.769230769230769,1.218891034221343,0.15390534821085033,2.035623409669211,2.0983832129342965,1.6982364467668192,2.222128698287109,0.19814151347766662,3.771551724137931,1.929158760278305,2.3114937031723257,1.806253890724513,1.6966827976518286,1.1657951399569364,2.4443999198557402,1.1358235909134113,2.980698753970193,2.541914548404543,8.7442218798151,null,4.2105263157894735,1.6118169981592063,3.4954407294832825,2.7896995708154506,2.7165297593313156,2.3414980998610484,3.4408602150537635,2.8368794326241136,null,2.0449212202480727,3.085109006789598,1.557976619301231,1.1781183061459877,5.109179563281747,0.8855435023245517,1.535894444602521,null,3.9877300613496933,0.6427110721589249,2.050473186119874,1.5910269355675026,1.0161662817551964,6.666666666666667,1.2353172194651718,1.598054542296335,2.064516129032258,1.541369928782908,3.519491628986924,2.6731533793680686,0.7976794778825236,2.094361334867664,7.054455445544554],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewid ...

# %% [markdown]
# ## Beyond just passing data: **Accelerating** third-party code
#
# Being able to pass these proxy objects to libraries like Plotly is great, but the benefits don't end there.
#
# When you enable cuDF's pandas accelerator mode, pandas operations running **inside the third-party library's functions** will also benefit from GPU acceleration where possible!
#
# Below, you can see an image illustrating how `cudf.pandas` can accelerate the pandas backend in Ibis, a library that provides a unified DataFrame API to various backends. We ran this example on a system with an NVIDIA H100 GPU and an Intel Xeon Platinum 8480CL CPU.
#
#
# By loading the `cudf.pandas` extension, pandas operations within Ibis can use the GPU with zero code change. It just works.

# %% [markdown]
# ![ibis](https://drive.google.com/uc?id=1uOJq2JtbgVb7tb8qw8a2gG3JRBo72t_H)

# %% [markdown]
# # Conclusion
#
# With cuDF's pandas accelerator mode, you can keep using pandas as your primary dataframe library. When things start to get a little slow, just load the `cudf.pandas` extension and run your existing code on a GPU!
#
# To learn more about `cudf.pandas`, we encourage you to visit [rapids.ai/cudf-pandas](https://rapids.ai/cudf-pandas).
