# %% [markdown]
# # 10 Minutes to cuDF's pandas accelerator mode (cudf.pandas)
#
# cuDF is a Python GPU DataFrame library (built on the Apache Arrow columnar memory format) for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API in the style of pandas.
#
# As of the v23.10 release, cuDF now provides a pandas accelerator mode (`cudf.pandas`), allowing you to bring accelerated computing to your pandas workflows without requiring any code change.
#
# This notebook is a short introduction to `cudf.pandas`.

# %%
# !pip install --upgrade pip --extra-index-url=https://pypi.nvidia.com cudf-cu11 dask-cudf-cu11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944/lib/python3.10/site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: cudf-cu11 in /databricks/python3/lib/python3.10/site-packages (23.10.2)
# Collecting cudf-cu11
#   Downloading https://pypi.nvidia.com/cudf-cu11/cudf_cu11-23.12.1-cp310-cp310-manylinux_2_28_x86_64.whl (506.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.4/506.4 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: dask-cudf-cu11 in /databricks/python3/lib/python3.10/site-packages (23.10.2)
# Collecting dask-cudf-cu11
#   Downloading https://pypi.nvidia.com/dask-cudf-cu11/dask_cudf_cu11-23.12.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25,>=1.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.23.5)
# Collecting pyarrow<15.0.0a0,>=14.0.1
#   Downloading pyarrow-14.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: cubinlinker-cu11 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (0.3.0.post1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.5.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (23.1)
# Requirement already satisfied: cachetools in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (5.3.1)
# Requirement already satisfied: rich in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (13.7.0)
# Requirement already satisfied: ptxcompiler-cu11 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (0.7.0.post1)
# Collecting rmm-cu11==23.12.*
#   Downloading https://pypi.nvidia.com/rmm-cu11/rmm_cu11-23.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=0.6.0 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (2023.12.2)
# Requirement already satisfied: pandas<1.6.0dev0,>=1.3 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (1.5.3)
# Requirement already satisfied: protobuf<5,>=4.21 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (4.23.3)
# Requirement already satisfied: numba<0.58,>=0.57 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (0.57.1)
# Requirement already satisfied: cuda-python<12.0a0,>=11.7.1 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (11.8.3)
# Requirement already satisfied: nvtx>=0.2.1 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (0.2.8)
# Requirement already satisfied: cupy-cuda11x>=12.0.0 in /databricks/python3/lib/python3.10/site-packages (from cudf-cu11) (12.3.0)
# Collecting rapids-dask-dependency==23.12.*
#   Downloading https://pypi.nvidia.com/rapids-dask-dependency/rapids_dask_dependency-23.12.1-py3-none-any.whl (5.4 kB)
# Collecting distributed==2023.11.0
#   Downloading distributed-2023.11.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.3 MB/s eta 0:00:00
# Collecting dask==2023.11.0
#   Downloading dask-2023.11.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.3.1 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (7.0.1)
# Requirement already satisfied: click>=8.1 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (3.0.0)
# Requirement already satisfied: partd>=1.2.0 in /databricks/python3/lib/python3.10/site-packages (from dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (1.4.1)
# Requirement already satisfied: psutil>=5.7.2 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (5.9.5)
# Requirement already satisfied: urllib3>=1.24.3 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (1.26.16)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (6.3.2)
# Requirement already satisfied: jinja2>=2.10.3 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (3.1.2)
# Requirement already satisfied: zict>=3.0.0 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (3.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (1.0.7)
# Requirement already satisfied: locket>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (1.0.0)
# Requirement already satisfied: fastrlock>=0.5 in /databricks/python3/lib/python3.10/site-packages (from cupy-cuda11x>=12.0.0->cudf-cu11) (0.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /databricks/python3/lib/python3.10/site-packages (from numba<0.58,>=0.57->cudf-cu11) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas<1.6.0dev0,>=1.3->cudf-cu11) (2023.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.10/site-packages (from rich->cudf-cu11) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.10/site-packages (from rich->cudf-cu11) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0dev0,>=1.3->cudf-cu11) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.13.0->dask==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed==2023.11.0->rapids-dask-dependency==23.12.*->dask-cudf-cu11) (2.1.3)
# Installing collected packages: pyarrow, pip, rmm-cu11, dask, distributed, cudf-cu11, rapids-dask-dependency, dask-cudf-cu11
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 12.0.1
#     Not uninstalling pyarrow at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
#   Attempting uninstall: rmm-cu11
#     Found existing installation: rmm-cu11 23.10.0
#     Not uninstalling rmm-cu11 at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'rmm-cu11'. No files were found to uninstall.
#   Attempting uninstall: dask
#     Found existing installation: dask 2023.9.2
#     Not uninstalling dask at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'dask'. No files were found to uninstall.
#   Attempting uninstall: distributed
#     Found existing installation: distributed 2023.9.2
#     Not uninstalling distributed at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'distributed'. No files were found to uninstall.
#   Attempting uninstall: cudf-cu11
#     Found existing installation: cudf-cu11 23.10.2
#     Not uninstalling cudf-cu11 at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'cudf-cu11'. No files were found to uninstall.
#   Attempting uninstall: dask-cudf-cu11
#     Found existing installation: dask-cudf-cu11 23.10.2
#     Not uninstalling dask-cudf-cu11 at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fe134494-0b5a-4307-9fa4-ae9487b4f944
#     Can't uninstall 'dask-cudf-cu11'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# raft-dask-cu11 23.10.0 requires dask==2023.9.2, but you have dask 2023.11.0 which is incompatible.
# raft-dask-cu11 23.10.0 requires distributed==2023.9.2, but you have distributed 2023.11.0 which is incompatible.
# pylibraft-cu11 23.10.0 requires rmm-cu11==23.10.*, but you have rmm-cu11 23.12.0 which is incompatible.
# dask-cuda 23.10.0 requires dask==2023.9.2, but you have dask 2023.11.0 which is incompatible.
# dask-cuda 23.10.0 requires distributed==2023.9.2, but you have distributed 2023.11.0 which is incompatible.
# cuml-cu11 23.10.0 requires cudf-cu11==23.10.*, but you have cudf-cu11 23.12.1 which is incompatible.
# cuml-cu11 23.10.0 requires dask==2023.9.2, but you have dask 2023.11.0 which is incompatible.
# cuml-cu11 23.10.0 requires dask-cudf-cu11==23.10.*, but you have dask-cudf-cu11 23.12.0 which is incompatible.
# cuml-cu11 23.10.0 requires distributed==2023.9.2, but you have distributed 2023.11.0 which is incompatible.
# Successfully installed cudf-cu11-23.12.1 dask-2023.11.0 dask-cudf-cu11-23.12.0 distributed-2023.11.0 pip-23.3.2 pyarrow-14.0.2 rapids-dask-dependency-23.12.1 rmm-cu11-23.12.0

# %% [markdown]
# # ⚠️ Verify your setup
#
# First, we'll verify that you are running with an NVIDIA GPU and that cuDF is available.
#
# If you haven't installed cuDF, please visit https://rapids.ai/#quick-start to choose your favorite installation method.

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------
# absl-py                      1.4.0
# asttokens                    2.2.1
# astunparse                   1.6.3
# backcall                     0.2.0
# blinker                      1.4
# bokeh                        3.2.2
# cachetools                   5.3.1
# certifi                      2023.7.22
# charset-normalizer           3.2.0
# click                        8.1.7
# cloudpickle                  3.0.0
# comm                         0.1.3
# contourpy                    1.1.0
# cryptography                 3.4.8
# cubinlinker-cu11             0.3.0.post1
# cuda-python                  11.8.3
# cudf-cu11                    23.12.1
# cuml-cu11                    23.10.0
# cupy-cuda11x                 12.3.0
# cycler                       0.11.0
# dask                         2023.11.0
# dask-cuda                    23.10.0
# dask-cudf-cu11               23.12.0
# dask-databricks              0.3.0
# dask-deltatable              0.3.1
# dask-glm                     0.3.2
# dask-ml                      2023.3.24
# databricks-sdk               0.1.6
# dbus-python                  1.2.18
# debugpy                      1.6.7
# decorator                    5.1.1
# deltalake                    0.13.0
# distlib                      0.3.7
# distributed                  2023.11.0
# distro                       1.7.0
# distro-info                  1.1build1
# executing                    1.2.0
# fastrlock                    0.8.2
# filelock                     3.12.2
# flatbuffers                  23.5.26
# fonttools                    4.41.1
# fsspec                       2023.12.2
# gast                         0.4.0
# google-auth                  2.22.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# googleapis-common-protos     1.60.0
# grpcio                       1.48.2
# grpcio-status                1.48.1
# h5py                         3.9.0
# httplib2                     0.20.2
# idna                         3.4
# importlib-metadata           7.0.1
# ipykernel                    6.25.0
# ipython                      8.14.0
# ipython-genutils             0.2.0
# jedi                         0.18.1
# jeepney                      0.7.1
# Jinja2                       3.1.2
# joblib                       1.3.2
# jupyter_client               8.3.0
# jupyter_core                 5.3.1
# keras                        2.13.1
# keyring                      23.5.0
# kiwisolver                   1.4.4
# launchpadlib                 1.10.16
# lazr.restfulclient           0.14.4
# lazr.uri                     1.0.6
# libclang                     16.0.6
# llvmlite                     0.40.1
# locket                       1.0.0
# lz4                          4.3.3
# Markdown                     3.4.4
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.3
# matplotlib                   3.7.0
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# more-itertools               8.10.0
# msgpack                      1.0.7
# multipledispatch             1.0.0
# nest-asyncio                 1.5.7
# numba                        0.57.1
# numpy                        1.23.5
# nvtx                         0.2.8
# oauthlib                     3.2.0
# opt-einsum                   3.3.0
# packaging                    23.1
# pandas                       1.5.3
# parso                        0.8.3
# partd                        1.4.1
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       10.0.0
# pip                          23.3.2
# platformdirs                 2.6.2
# prompt-toolkit               3.0.39
# protobuf                     4.23.3
# psutil                       5.9.5
# ptxcompiler-cu11             0.7.0.post1
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyarrow                      14.0.2
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# Pygments                     2.15.1
# PyGObject                    3.42.1
# PyJWT                        2.3.0
# pylibraft-cu11               23.10.0
# pynvml                       11.4.1
# pyparsing                    2.4.7
# python-apt                   2.4.0+ubuntu1
# python-dateutil              2.8.2
# pytz                         2023.3
# PyYAML                       6.0.1
# pyzmq                        25.1.0
# raft-dask-cu11               23.10.0
# rapids-dask-dependency       23.12.1
# requests                     2.28.2
# requests-oauthlib            1.3.1
# rich                         13.7.0
# rmm-cu11                     23.12.0
# rsa                          4.9
# scikit-learn                 1.3.2
# scipy                        1.11.4
# SecretStorage                3.3.1
# setuptools                   65.5.1
# six                          1.16.0
# sortedcontainers             2.4.0
# sparse                       0.15.1
# stack-data                   0.6.2
# tblib                        3.0.0
# tensorboard                  2.13.0
# tensorboard-data-server      0.7.1
# tensorflow                   2.13.0
# tensorflow-estimator         2.13.0
# tensorflow-io-gcs-filesystem 0.32.0
# termcolor                    2.3.0
# threadpoolctl                3.2.0
# toolz                        0.12.0
# tornado                      6.3.2
# traitlets                    5.9.0
# treelite                     3.9.1
# treelite-runtime             3.9.1
# typing_extensions            4.5.0
# ucx-py-cu11                  0.34.0
# unattended-upgrades          0.1
# urllib3                      1.26.16
# virtualenv                   20.16.7
# wadllib                      1.3.6
# wcwidth                      0.2.6
# Werkzeug                     2.3.6
# wheel                        0.38.4
# wrapt                        1.15.0
# xgboost                      2.0.3
# xyzservices                  2023.10.1
# zict                         3.0.0
# zipp                         1.0.0

# %%
# !nvidia-smi  # this should display information about available GPUs
# Out:
# Wed Jan 17 11:10:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:1E.0 Off |                    0 |
# | N/A   19C    P8              11W /  70W |      2MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import cudf  # this should work without any errors

# %% [markdown]
# We'll also install `plotly-express` for visualizing data.

# %%
#!pip install plotly_express

# %% [markdown]
# # Download the data
#
# The data we'll be working with is the [Parking Violations Issued - Fiscal Year 2022](https://data.cityofnewyork.us/City-Government/Parking-Violations-Issued-Fiscal-Year-2022/7mxj-7a6y) dataset from NYC Open Data.
#
# We're downloading a copy of this dataset from an s3 bucket hosted by NVIDIA to provide faster download speeds. We'll start by downloading the data. This should take about 30 seconds.
#
# ## Data License and Terms
# As this dataset originates from the NYC Open Data Portal, it's governed by their license and terms of use.
#
# ### Are there restrictions on how I can use Open Data?
#
# > Open Data belongs to all New Yorkers. There are no restrictions on the use of Open Data. Refer to Terms of Use for more information.
#
# ### [Terms of Use](https://opendata.cityofnewyork.us/overview/#termsofuse)
#
# > By accessing datasets and feeds available through NYC Open Data, the user agrees to all of the Terms of Use of NYC.gov as well as the Privacy Policy for NYC.gov. The user also agrees to any additional terms of use defined by the agencies, bureaus, and offices providing data. Public data sets made available on NYC Open Data are provided for informational purposes. The City does not warranty the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set made available on NYC Open Data, nor are any such warranties to be implied or inferred with respect to the public data sets furnished therein.
#
# > The City is not liable for any deficiencies in the completeness, accuracy, content, or fitness for any particular purpose or use of any public data set, or application utilizing such data set, provided by any third party.
#
# > Submitting City Agencies are the authoritative source of data available on NYC Open Data. These entities are responsible for data quality and retain version control of data sets and feeds accessed on the Site. Data may be updated, corrected, or refreshed at any time.

# %%
# !wget https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Out:
# --2024-01-17 11:10:53--  https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Resolving data.rapids.ai (data.rapids.ai)... 204.246.191.16, 204.246.191.112, 204.246.191.75, ...
# Connecting to data.rapids.ai (data.rapids.ai)|204.246.191.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477161608 (455M) [binary/octet-stream]
# Saving to: ‘nyc_parking_violations_2022.parquet’
#
# nyc_parking_violati 100%[===================>] 455.06M  33.8MB/s    in 16s
#
# 2024-01-17 11:11:10 (29.2 MB/s) - ‘nyc_parking_violations_2022.parquet’ saved [477161608/477161608]

# %% [markdown]
# # Analysis using Standard Pandas
#
# First, let's use Pandas to read in some columns of the dataset:

# %%
import pandas as pd

# %%
# read 5 columns data:
df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

# view a random sample of 10 rows:
df.sample(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>Vehicle Body Type</th>
#       <th>Issue Date</th>
#       <th>Summons Number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3620710</th>
#       <td>NY</td>
#       <td>20-No Parking (Com Plate)</td>
#       <td>VAN</td>
#       <td>09/22/2021</td>
#       <td>8858832280</td>
#     </tr>
#     <tr>
#       <th>9938779</th>
#       <td>TX</td>
#       <td>40-Fire Hydrant</td>
#       <td>2DSD</td>
#       <td>02/14/2022</td>
#       <td>8962643777</td>
#     </tr>
#     <tr>
#       <th>13201721</th>
#       <td>NY</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>2DSD</td>
#       <td>04/27/2022</td>
#       <td>4777188838</td>
#     </tr>
#     <tr>
#       <th>6096049</th>
#       <td>NY</td>
#       <td>FAILURE TO STOP AT RED LIGHT</td>
#       <td>VAN</td>
#       <td>10/26/2021</td>
#       <td>5117876726</td>
#     </tr>
#     <tr>
#       <th>785851</th>
#       <td>NY</td>
#       <td>19-No Stand (bus stop)</td>
#       <td>VAN</td>
#       <td>07/16/2021</td>
#       <td>8951315381</td>
#     </tr>
#     <tr>
#       <th>8298974</th>
#       <td>NJ</td>
#       <td>BUS LANE VIOLATION</td>
#       <td>PV</td>
#       <td>12/21/2021</td>
#       <td>4021727000</td>
#     </tr>
#     <tr>
#       <th>13054096</th>
#       <td>NY</td>
#       <td>&lt;NA&gt;</td>
#       <td>SDN</td>
#       <td>05/13/2022</td>
#       <td>1471696534</td>
#     </tr>
#     <tr>
#       <th>11204869</th>
#       <td>IN</td>
#       <td>69-Fail to Dsp Prking Mtr Rcpt</td>
#       <td>TRAC</td>
#       <td>03/16/2022</td>
#       <td>8914800350</td>
#     </tr>
#     <tr>
#       <th>8308907</th>
#       <td>NY</td>
#       <td>BUS LANE VIOLATION</td>
#       <td>SUBN</td>
#       <td>12/28/2021</td>
#       <td>4021831794</td>
#     </tr>
#     <tr>
#       <th>10603176</th>
#       <td>NY</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>SUBN</td>
#       <td>03/16/2022</td>
#       <td>4771579751</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Next, we'll try to answer a few questions using the data.

# %% [markdown]
# ## Which parking violation is most commonly committed by vehicles from various U.S states?
#
# Each record in our dataset contains the state of registration of the offending vehicle, and the type of parking offence. Let's say we want to get the most common type of offence for vehicles registered in different states. We can do this in Pandas using a combination of [value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html) and [GroupBy.head](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.head.html):

# %%
(
    df[["Registration State", "Violation Description"]]  # get only these two columns
    .value_counts()  # get the count of offences per state and per type of offence
    .groupby("Registration State")  # group by state
    .head(
        1
    )  # get the first row in each group (the type of offence with the largest count)
    .sort_index()  # sort by state name
    .reset_index()
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99</td>
#       <td>74-Missing Display Plate</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AB</td>
#       <td>14-No Standing</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AK</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AL</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3668</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AR</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>537</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>VT</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3024</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>WA</td>
#       <td>21-No Parking (street clean)</td>
#       <td>3732</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>WI</td>
#       <td>14-No Standing</td>
#       <td>1639</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>WV</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>WY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>138</td>
#     </tr>
#   </tbody>
# </table>
# <p>65 rows × 3 columns</p>
# </div>

# %% [markdown]
# The code above uses [method chaining](https://tomaugspurger.net/posts/method-chaining/) to combine a series of operations into a single statement. You might find it useful to break the code up into multiple statements and inspect each of the intermediate results!

# %% [markdown]
# ## Which vehicle body types are most frequently involved in parking violations?
#
# We can also investigate which vehicle body types most commonly appear in parking violations

# %%
(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th>Vehicle Body Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SUBN</th>
#       <td>6449007</td>
#     </tr>
#     <tr>
#       <th>4DSD</th>
#       <td>4402991</td>
#     </tr>
#     <tr>
#       <th>VAN</th>
#       <td>1317899</td>
#     </tr>
#     <tr>
#       <th>DELV</th>
#       <td>436430</td>
#     </tr>
#     <tr>
#       <th>PICK</th>
#       <td>429798</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>CARY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ISUZ</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>IXMR</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BILB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ONEL</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>966 rows × 1 columns</p>
# </div>

# %% [markdown]
# ## How do parking violations vary across days of the week?

# %%
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# Out[11]: issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %% [markdown]
# It looks like there are fewer violations on weekends, which makes sense! During the week, more people are driving in New York City.

# %% [markdown]
# ## Let's time it!
#
# Loading and processing this data took a little time. Let's measure how long these pipelines take in Pandas:

# %%
# %%time

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

(
    df[["Registration State", "Violation Description"]]
    .value_counts()
    .groupby("Registration State")
    .head(1)
    .sort_index()
    .reset_index()
)
# Out:
# CPU times: user 10.9 s, sys: 3.3 s, total: 14.2 s
# Wall time: 11.4 s
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Registration State</th>
#       <th>Violation Description</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99</td>
#       <td>74-Missing Display Plate</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AB</td>
#       <td>14-No Standing</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AK</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AL</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3668</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AR</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>537</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>VT</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>3024</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>WA</td>
#       <td>21-No Parking (street clean)</td>
#       <td>3732</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>WI</td>
#       <td>14-No Standing</td>
#       <td>1639</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>WV</td>
#       <td>PHTO SCHOOL ZN SPEED VIOLATION</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>WY</td>
#       <td>21-No Parking (street clean)</td>
#       <td>138</td>
#     </tr>
#   </tbody>
# </table>
# <p>65 rows × 3 columns</p>
# </div>

# %%
# %%time

(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)
# Out:
# CPU times: user 2.41 s, sys: 173 ms, total: 2.58 s
# Wall time: 2.57 s
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th>Vehicle Body Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SUBN</th>
#       <td>6449007</td>
#     </tr>
#     <tr>
#       <th>4DSD</th>
#       <td>4402991</td>
#     </tr>
#     <tr>
#       <th>VAN</th>
#       <td>1317899</td>
#     </tr>
#     <tr>
#       <th>DELV</th>
#       <td>436430</td>
#     </tr>
#     <tr>
#       <th>PICK</th>
#       <td>429798</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>CARY</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ISUZ</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>IXMR</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>BILB</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ONEL</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>966 rows × 1 columns</p>
# </div>

# %%
# %%time

weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()
# Out:
# CPU times: user 5.53 s, sys: 653 ms, total: 6.18 s
# Wall time: 6.18 s
# Out[14]: issue_weekday
# Sunday        462992
# Saturday     1108385
# Monday       2488563
# Wednesday    2760088
# Tuesday      2809949
# Friday       2891679
# Thursday     2913951
# Name: Summons Number, dtype: int64

# %% [markdown]
# # Using cuDF's pandas accelerator mode (cudf.pandas)
#
# Now, let's re-run the Pandas code above with the `cudf.pandas` extension loaded.
#
# Typically, you should load the `cudf.pandas` extension as the first step in your notebook, before importing any modules. Here, we explicitly restart the kernel to simulate that behavior.

# %%
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# Out[15]: {'status': 'ok', 'restart': True}

# %%
# %pip install  /dbfs/FileStore/cudf_private_cu11-23.10.0.231106-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl --extra-index-url https://pypi.nvidia.com rmm-cu11

# %%
# %pip install --upgrade pip plotly_express==0.4.1 nbformat

# %%
# !pip list

# %%
# !pip install --upgrade pip --extra-index-url=https://pypi.nvidia.com cudf-cu11 dask-cudf-cu11

# %%
# %load_ext cudf.pandas

# %%
# %%time

import pandas as pd

df = pd.read_parquet(
    "nyc_parking_violations_2022.parquet",
    columns=[
        "Registration State",
        "Violation Description",
        "Vehicle Body Type",
        "Issue Date",
        "Summons Number",
    ],
)

(
    df[["Registration State", "Violation Description"]]
    .value_counts()
    .groupby("Registration State")
    .head(1)
    .sort_index()
    .reset_index()
)

# %%
# %%time

(
    df.groupby(["Vehicle Body Type"])
    .agg({"Summons Number": "count"})
    .rename(columns={"Summons Number": "Count"})
    .sort_values(["Count"], ascending=False)
)

# %%
# %%time

weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday",
}

df["Issue Date"] = df["Issue Date"].astype("datetime64[ms]")
df["issue_weekday"] = df["Issue Date"].dt.weekday.map(weekday_names)

df.groupby(["issue_weekday"])["Summons Number"].count().sort_values()

# %% [markdown]
# Much faster! Operations that took 5-20 seconds can now potentially finish in just milliseconds without changing any code.

# %% [markdown]
# # Understanding Performance
#
# cuDF's pandas accelerator mode provides profiling utilities to help you better understand performance. With these tools, you can identify which parts of your code ran on the GPU and which parts ran on the CPU.
#
# They're accessible in the `cudf.pandas` namespace since the `cudf.pandas` extension was loaded above with `load_ext cudf.pandas`.
#
# #### Colab Note
# If you're running in Colab, the first time you run use the profiler it may take 10+ seconds due to Colab's debugger interacting with the built-in Python function [sys.settrace](https://docs.python.org/3/library/sys.html#sys.settrace) that we use for profiling. For demo purposes, this isn't an issue. Just run the cell again.
#
# ## Profiling Functionality
#
# We can generate a per-function profile:

# %%
# %%cudf.pandas.profile
#
# small_df = pd.DataFrame({'a': [0, 1, 2], 'b': ["x", "y", "z"]})
# small_df = pd.concat([small_df, small_df])
#
# axis = 0
# for i in range(0, 2):
#     small_df.min(axis=axis)
#     axis = 1
#
# counts = small_df.groupby("a").b.count()

# %%
# %%cudf.pandas.line_profile
#
# small_df = pd.DataFrame({'a': [0, 1, 2], 'b': ["x", "y", "z"]})
# small_df = pd.concat([small_df, small_df])
#
# axis = 0
# for i in range(0, 2):
#     small_df.min(axis=axis)
#     axis = 1
#
# counts = small_df.groupby("a").b.count()

# %% [markdown]
# ## Behind the scenes: What's going on here?
#
# When you load cuDF's pandas accelerator mode, Pandas types like `Series` and `DataFrame` are replaced by proxy objects that dispatch operations to cuDF when possible. We can verify that `cudf.pandas` is active by looking at our `pd` variable:

# %%
pd

# %% [markdown]
# As a result, all pandas functions, methods, and created objects are proxies:

# %%
type(pd.read_csv)

# %% [markdown]
# Operations supported by cuDF will be **very** fast:

# %%
# %%time
df.count(axis=0)

# %% [markdown]
# Operations not supported by cuDF will be slower, as they fall back to using Pandas (copying data between the CPU and GPU under the hood as needed). For example, cuDF does not currently support the `axis=` parameter to the `count` method. So this operation will run on the CPU and be noticeably slower than the previous one.

# %%
# %%time
df.count(
    axis=1
)  # This will use pandas, because cuDF doesn't support axis=1 for the .count() method

# %% [markdown]
# But the story doesn't end here. We often need to mix our own code with third-party libraries that other people have written. Many of these libraries accept pandas objects as inputs.

# %% [markdown]
# # Using third-party libraries with cuDF's pandas accelerator mode
#
# You can pass Pandas objects to third-party libraries when using `cudf.pandas`, just like you would when using regular Pandas.
#
# Below, we show an example of using [plotly-express](https://plotly.com/python/plotly-express/) to visualize the data we've been processing:

# %% [markdown]
# ## Visualizing which states have more pickup trucks relative to other vehicles?

# %%
import plotly.express as px

df = df.rename(
    columns={
        "Registration State": "reg_state",
        "Vehicle Body Type": "vehicle_type",
    }
)

# vehicle counts per state:
counts = df.groupby("reg_state").size().sort_index()
# vehicles with type "PICK" (Pickup Truck)
pickup_counts = df.where(df["vehicle_type"] == "PICK").groupby("reg_state").size()
# percentage of pickup trucks by state:
pickup_frac = ((pickup_counts / counts) * 100).rename("% Pickup Trucks")
del pickup_frac["MB"]  # (Manitoba is a huge outlier!)

# plot the results:
pickup_frac = pickup_frac.reset_index()
fig = px.choropleth(
    pickup_frac,
    locations="reg_state",
    color="% Pickup Trucks",
    locationmode="USA-states",
    scope="usa",
)

fig.show(renderer="databricks")

# %% [markdown]
# ## Beyond just passing data: **Accelerating** third-party code
#
# Being able to pass these proxy objects to libraries like Plotly is great, but the benefits don't end there.
#
# When you enable cuDF's pandas accelerator mode, pandas operations running **inside the third-party library's functions** will also benefit from GPU acceleration where possible!
#
# Below, you can see an image illustrating how `cudf.pandas` can accelerate the pandas backend in Ibis, a library that provides a unified DataFrame API to various backends. We ran this example on a system with an NVIDIA H100 GPU and an Intel Xeon Platinum 8480CL CPU.
#
#
# By loading the `cudf.pandas` extension, pandas operations within Ibis can use the GPU with zero code change. It just works.

# %% [markdown]
# ![ibis](https://drive.google.com/uc?id=1uOJq2JtbgVb7tb8qw8a2gG3JRBo72t_H)

# %% [markdown]
# # Conclusion
#
# With cuDF's pandas accelerator mode, you can keep using pandas as your primary dataframe library. When things start to get a little slow, just load the `cudf.pandas` extension and run your existing code on a GPU!
#
# To learn more about `cudf.pandas`, we encourage you to visit [rapids.ai/cudf-pandas](https://rapids.ai/cudf-pandas).
